# %% [markdown]
# ### This notebook contains POC - to extract key value pairs and other layout related information from documents and images using OCR

# %%
import os
import openai
import dotenv
from azure.core.credentials import AzureKeyCredential
from azure.ai.documentintelligence import DocumentIntelligenceClient
from azure.ai.documentintelligence.models import DocumentAnalysisFeature, AnalyzeResult

from azure.core.credentials import AzureKeyCredential
from azure.ai.formrecognizer import DocumentAnalysisClient


dotenv.load_dotenv("..\\common\\credentials.env", override=True)
# Out:
# True

# %% [markdown]
# #### Set variables

# %%
"""
This code sample shows Prebuilt Document operations with the Azure Form Recognizer client library. 
The async versions of the samples require Python 3.6 or later.

To learn more, please visit the documentation - Quickstart: Form Recognizer Python client library SDKs
https://learn.microsoft.com/azure/applied-ai-services/form-recognizer/quickstarts/get-started-v3-sdk-rest-api?view=doc-intel-3.1.0&pivots=programming-language-python
"""

"""
Remember to remove the key from your code when you're done, and never post it publicly. For production, use
secure methods to store and access your credentials. For more information, see 
https://docs.microsoft.com/en-us/azure/cognitive-services/cognitive-services-security?tabs=command-line%2Ccsharp#environment-variables-and-application-configuration
"""
path_to_sample_documents = "..\\common\\data\\sampleinvoice.jpeg"
endpoint = os.environ["DOCUMENTINTELLIGENCE_ENDPOINT"]
key = os.environ["DOCUMENTINTELLIGENCE_API_KEY"]

# %% [markdown]
# #### read input document and analyze using Document Intelligence

# %%
# sample document
document_analysis_client = DocumentAnalysisClient(
        endpoint=endpoint, credential=AzureKeyCredential(key)
    )

#using General Document model

with open(path_to_sample_documents, "rb") as f:
       poller = document_analysis_client.begin_analyze_document(
           "prebuilt-document", document=f, locale="en-US"
       )

#Alternatively, you can use FormURL to analyze the document
#formUrl = "https://raw.githubusercontent.com/Azure-Samples/cognitive-services-REST-api-samples/master/curl/form-recognizer/sample-layout.pdf"
#poller = document_analysis_client.begin_analyze_document_from_url("prebuilt-document", formUrl)


result = poller.result()

# %% [markdown]
# ##### Notes:
# The General document model combines powerful Optical Character Recognition (OCR) capabilities with deep learning models to extract key-value pairs, tables, and selection marks from documents.
# Starting with Document Intelligence versions 2024-02-29-preview, 2023-10-31-preview and going forward, the general document model (prebuilt-document) is deprecated. To extract key-value pairs, selection marks, text, tables, and structure from documents, use the following models:
#
# Layout model with the optional query string parameter features=keyValuePairs enabled.  VERSION: • v4:2024-02-29-preview • v3.1:2023-07-31 (GA) || Model ID prebuilt-layout

# %% [markdown]
# #### Extract KV pairs

# %%
print("----Key-value pairs found in document----")
for kv_pair in result.key_value_pairs:
    if kv_pair.key and kv_pair.value:
        print("Key '{}': Value: '{}'".format(kv_pair.key.content, kv_pair.value.content))
    else:
        print("Key '{}': Value:".format(kv_pair.key.content))

print("----------------------------------------")
# Out:
# ----Key-value pairs found in document----
# Key 'Invoice No.': Value: 'INV09080012'
# Key 'Date': Value: '14-Aug-2009'
# Key 'Tel:': Value: '(415) 989-1188'
# Key 'Fax:': Value: '(415) 989-2288'
# Key 'Email:': Value: 'admin@xincube.com'
# Key 'Website:': Value: 'www.xincube.com'
# Key 'Bill To': Value: 'John
# Synex Inc
# 128 AA Juanita Ave, 91740 Glendora, CA, US'
# Key 'Ship To': Value: 'John
# Synex Inc
# 128 AA Juanita Ave, 91740 Glendora, CA, US'
# Key 'Sales Person': Value:
# Key 'Order No': Value:
# Key 'Shipping Date': Value: '13-Aug-2009'
# Key 'Shipping Terms': Value:
# Key 'Terms': Value: 'COD'
# Key 'Sub Total (USD)': Value: '9,463.00'
# Key 'Discount (USD)': Value: '0.00'
# Key 'Shipping (USD)': Value: '0.00'
# Key 'Total (USD)': Value: '10,243.70'
# Key 'Sales Tax (USD)': Value: '780.70'
# Key 'Deposit (USD)': Value: '0.00'
# Key 'Amount Due (USD)': Value: '10,243.70'
# ----------------------------------------

# %% [markdown]
# #### Extract Tables, Rows and Cells

# %%
if result.tables:
    for table_idx, table in enumerate(result.tables):
        print(f"Table # {table_idx} has {table.row_count} rows and {table.column_count} columns")
        if table.bounding_regions:
            for region in table.bounding_regions:
                print(f"Table # {table_idx} location on page: {region.page_number} is {region.polygon}")
        for cell in table.cells:
            print(f"...Cell[{cell.row_index}][{cell.column_index}] has text '{cell.content}'")
            if cell.bounding_regions:
                for region in cell.bounding_regions:
                    print(
                        f"...content on page {region.page_number} is within bounding polygon '{region.polygon}'\n"
                    )
print("----------------------------------------")
# Out:
# Table # 0 has 2 rows and 5 columns
# Table # 0 location on page: 1 is [Point(x=49.0, y=558.0), Point(x=1161.0, y=558.0), Point(x=1161.0, y=635.0), Point(x=49.0, y=635.0)]
# ...Cell[0][0] has text 'Sales Person'
# ...content on page 1 is within bounding polygon '[Point(x=53.0, y=558.0), Point(x=222.0, y=558.0), Point(x=222.0, y=596.0), Point(x=52.0, y=596.0)]'
#
# ...Cell[0][1] has text 'Order No'
# ...content on page 1 is within bounding polygon '[Point(x=222.0, y=558.0), Point(x=424.0, y=558.0), Point(x=424.0, y=596.0), Point(x=222.0, y=596.0)]'
#
# ...Cell[0][2] has text 'Shipping Date'
# ...content on page 1 is within bounding polygon '[Point(x=424.0, y=558.0), Point(x=669.0, y=558.0), Point(x=669.0, y=596.0), Point(x=424.0, y=596.0)]'
#
# ...Cell[0][3] has text 'Shipping Terms'
# ...content on page 1 is within bounding polygon '[Point(x=669.0, y=558.0), Point(x=900.0, y=558.0), Point(x=900.0, y=596.0), Point(x=669.0, y=596.0)]'
#
# ...Cell[0][4] has text 'Terms'
# ...content on page 1 is within bounding polygon '[Point(x=900.0, y=558.0), Point(x=1089.0, y=558.0), Point(x=1089.0, y=596.0), Point(x=900.0, y=596.0)]'
#
# ...Cell[1][0] has text ''
# ...content on page 1 is within bounding polygon '[Point(x=52.0, y=596.0), Point(x=222.0, y=596.0), Point(x=222.0, y=633.0), Point(x=52.0, y=633.0)]'
#
# ...Cell[1][1] has text ''
# ...content on page 1 is within bounding polygon '[Point(x=222.0, y=596.0), Point(x=424.0, y=596.0), Point(x=424.0, y=633.0), Point(x=222.0, y=633.0)]'
#
# ...Cell[1][2] has text '13-Aug-2009'
# ...content on page 1 is within bounding polygon '[Point(x=424.0, y=596.0), Point(x=669.0, y=596.0), Point(x=669.0, y=633.0), Point(x=424.0, y=633.0)]'
#
# ...Cell[1][3] has text ''
# ...content on page 1 is within bounding polygon '[Point(x=669.0, y=596.0), Point(x=900.0, y=596.0), Point(x=900.0, y=633.0), Point(x=669.0, y=633.0)]'
#
# ...Cell[1][4] has text 'COD'
# ...content on page 1 is within bounding polygon '[Point(x=900.0, y=596.0), Point(x=1089.0, y=596.0), Point(x=1089.0, y=633.0), Point(x=900.0, y=633.0)]'
#
# Table # 1 has 5 rows and 4 columns
# Table # 1 location on page: 1 is [Point(x=48.0, y=635.0), Point(x=1165.0, y=635.0), Point(x=1165.0, y=884.0), Point(x=48.0, y=884.0)]
# ...Cell[0][0] has text 'Qty'
# ...content on page 1 is within bounding polygon '[Point(x=52.0, y=636.0), Point(x=305.0, y=636.0), Point(x=305.0, y=684.0), Point(x=52.0, y=684.0)]'
#
# ...Cell[0][1] has text 'SKU / Description'
# ...content on page 1 is within bounding polygon '[Point(x=305.0, y=636.0), Point(x=832.0, y=636.0), Point(x=832.0, y=684.0), Point(x=305.0, y=684.0)]'
#
# ...Cell[0][2] has text 'Unit Price (USD)'
# ...content on page 1 is within bounding polygon '[Point(x=832.0, y=636.0), Point(x=1005.0, y=636.0), Point(x=1005.0, y=685.0), Point(x=832.0, y=684.0)]'
#
# ...Cell[0][3] has text 'Amount (USD)'
# ...content on page 1 is within bounding polygon '[Point(x=1005.0, y=636.0), Point(x=1161.0, y=636.0), Point(x=1161.0, y=685.0), Point(x=1005.0, y=685.0)]'
#
# ...Cell[1][0] has text '6.00'
# ...content on page 1 is within bounding polygon '[Point(x=52.0, y=684.0), Point(x=305.0, y=684.0), Point(x=305.0, y=742.0), Point(x=51.0, y=743.0)]'
#
# ...Cell[1][1] has text 'AMD Athlon X2DC-7450, 2.4GHz/1GB/160GB/SMP-DVD/VB'
# ...content on page 1 is within bounding polygon '[Point(x=305.0, y=684.0), Point(x=832.0, y=684.0), Point(x=832.0, y=742.0), Point(x=305.0, y=742.0)]'
#
# ...Cell[1][2] has text '580.00'
# ...content on page 1 is within bounding polygon '[Point(x=832.0, y=684.0), Point(x=1005.0, y=685.0), Point(x=1005.0, y=742.0), Point(x=832.0, y=742.0)]'
#
# ...Cell[1][3] has text '3,480.00'
# ...content on page 1 is within bounding polygon '[Point(x=1005.0, y=685.0), Point(x=1161.0, y=685.0), Point(x=1161.0, y=741.0), Point(x=1005.0, y=742.0)]'
#
# ...Cell[2][0] has text '4.00'
# ...content on page 1 is within bounding polygon '[Point(x=51.0, y=743.0), Point(x=305.0, y=742.0), Point(x=303.0, y=785.0), Point(x=51.0, y=785.0)]'
#
# ...Cell[2][1] has text 'PDC-E5300 - 2.6GHZ/1GB/320GB/SMP-DVD/FDD/VB'
# ...content on page 1 is within bounding polygon '[Point(x=305.0, y=742.0), Point(x=832.0, y=742.0), Point(x=832.0, y=785.0), Point(x=303.0, y=785.0)]'
#
# ...Cell[2][2] has text '645.00'
# ...content on page 1 is within bounding polygon '[Point(x=832.0, y=742.0), Point(x=1005.0, y=742.0), Point(x=1005.0, y=785.0), Point(x=832.0, y=785.0)]'
#
# ...Cell[2][3] has text '2,580.00'
# ...content on page 1 is within bounding polygon '[Point(x=1005.0, y=742.0), Point(x=1161.0, y=741.0), Point(x=1161.0, y=785.0), Point(x=1005.0, y=785.0)]'
#
# ...Cell[3][0] has text '10.00'
# ...content on page 1 is within bounding polygon '[Point(x=51.0, y=785.0), Point(x=303.0, y=785.0), Point(x=303.0, y=838.0), Point(x=50.0, y=839.0)]'
#
# ...Cell[3][1] has text 'LG 18.5" WLCD'
# ...content on page 1 is within bounding polygon '[Point(x=303.0, y=785.0), Point(x=832.0, y=785.0), Point(x=832.0, y=838.0), Point(x=303.0, y=838.0)]'
#
# ...Cell[3][2] has text '230.00'
# ...content on page 1 is within bounding polygon '[Point(x=832.0, y=785.0), Point(x=1005.0, y=785.0), Point(x=1005.0, y=838.0), Point(x=832.0, y=838.0)]'
#
# ...Cell[3][3] has text '2,300.00'
# ...content on page 1 is within bounding polygon '[Point(x=1005.0, y=785.0), Point(x=1161.0, y=785.0), Point(x=1161.0, y=838.0), Point(x=1005.0, y=838.0)]'
#
# ...Cell[4][0] has text '1.00'
# ...content on page 1 is within bounding polygon '[Point(x=50.0, y=839.0), Point(x=303.0, y=838.0), Point(x=303.0, y=885.0), Point(x=50.0, y=885.0)]'
#
# ...Cell[4][1] has text 'HP LaserJet 5200'
# ...content on page 1 is within bounding polygon '[Point(x=303.0, y=838.0), Point(x=832.0, y=838.0), Point(x=832.0, y=885.0), Point(x=303.0, y=885.0)]'
#
# ...Cell[4][2] has text '1,103.00'
# ...content on page 1 is within bounding polygon '[Point(x=832.0, y=838.0), Point(x=1005.0, y=838.0), Point(x=1005.0, y=885.0), Point(x=832.0, y=885.0)]'
#
# ...Cell[4][3] has text '1,103.00'
# ...content on page 1 is within bounding polygon '[Point(x=1005.0, y=838.0), Point(x=1161.0, y=838.0), Point(x=1163.0, y=885.0), Point(x=1005.0, y=885.0)]'
#
# Table # 2 has 4 rows and 4 columns
# Table # 2 location on page: 1 is [Point(x=48.0, y=1129.0), Point(x=1166.0, y=1129.0), Point(x=1165.0, y=1287.0), Point(x=48.0, y=1287.0)]
# ...Cell[0][0] has text 'Sub Total (USD)'
# ...content on page 1 is within bounding polygon '[Point(x=49.0, y=1129.0), Point(x=325.0, y=1129.0), Point(x=325.0, y=1167.0), Point(x=49.0, y=1167.0)]'
#
# ...Cell[0][1] has text 'Discount (USD)'
# ...content on page 1 is within bounding polygon '[Point(x=325.0, y=1129.0), Point(x=603.0, y=1129.0), Point(x=603.0, y=1167.0), Point(x=325.0, y=1167.0)]'
#
# ...Cell[0][2] has text 'Shipping (USD)'
# ...content on page 1 is within bounding polygon '[Point(x=603.0, y=1129.0), Point(x=881.0, y=1129.0), Point(x=881.0, y=1167.0), Point(x=603.0, y=1167.0)]'
#
# ...Cell[0][3] has text 'Total (USD)'
# ...content on page 1 is within bounding polygon '[Point(x=881.0, y=1129.0), Point(x=1161.0, y=1129.0), Point(x=1161.0, y=1167.0), Point(x=881.0, y=1167.0)]'
#
# ...Cell[1][0] has text '9,463.00'
# ...content on page 1 is within bounding polygon '[Point(x=49.0, y=1167.0), Point(x=325.0, y=1167.0), Point(x=325.0, y=1203.0), Point(x=49.0, y=1203.0)]'
#
# ...Cell[1][1] has text '0.00'
# ...content on page 1 is within bounding polygon '[Point(x=325.0, y=1167.0), Point(x=603.0, y=1167.0), Point(x=603.0, y=1203.0), Point(x=325.0, y=1203.0)]'
#
# ...Cell[1][2] has text '0.00'
# ...content on page 1 is within bounding polygon '[Point(x=603.0, y=1167.0), Point(x=881.0, y=1167.0), Point(x=881.0, y=1204.0), Point(x=603.0, y=1203.0)]'
#
# ...Cell[1][3] has text '10,243.70'
# ...content on page 1 is within bounding polygon '[Point(x=881.0, y=1167.0), Point(x=1161.0, y=1167.0), Point(x=1161.0, y=1204.0), Point(x=881.0, y=1204.0)]'
#
# ...Cell[2][0] has text 'Sales Tax (USD)'
# ...content on page 1 is within bounding polygon '[Point(x=49.0, y=1203.0), Point(x=325.0, y=1203.0), Point(x=325.0, y=1242.0), Point(x=49.0, y=1242.0)]'
#
# ...Cell[2][1] has text ''
# ...content on page 1 is within bounding polygon '[Point(x=325.0, y=1203.0), Point(x=603.0, y=1203.0), Point(x=603.0, y=1242.0), Point(x=325.0, y=1242.0)]'
#
# ...Cell[2][2] has text ''
# ...content on page 1 is within bounding polygon '[Point(x=603.0, y=1203.0), Point(x=881.0, y=1204.0), Point(x=881.0, y=1242.0), Point(x=603.0, y=1242.0)]'
#
# ...Cell[2][3] has text 'Deposit (USD)'
# ...content on page 1 is within bounding polygon '[Point(x=881.0, y=1204.0), Point(x=1161.0, y=1204.0), Point(x=1163.0, y=1242.0), Point(x=881.0, y=1242.0)]'
#
# ...Cell[3][0] has text '780.70'
# ...content on page 1 is within bounding polygon '[Point(x=49.0, y=1242.0), Point(x=325.0, y=1242.0), Point(x=323.0, y=1283.0), Point(x=49.0, y=1283.0)]'
#
# ...Cell[3][1] has text ''
# ...content on page 1 is within bounding polygon '[Point(x=325.0, y=1242.0), Point(x=603.0, y=1242.0), Point(x=603.0, y=1283.0), Point(x=323.0, y=1283.0)]'
#
# ...Cell[3][2] has text ''
# ...content on page 1 is within bounding polygon '[Point(x=603.0, y=1242.0), Point(x=881.0, y=1242.0), Point(x=881.0, y=1283.0), Point(x=603.0, y=1283.0)]'
#
# ...Cell[3][3] has text '0.00'
# ...content on page 1 is within bounding polygon '[Point(x=881.0, y=1242.0), Point(x=1163.0, y=1242.0), Point(x=1163.0, y=1283.0), Point(x=881.0, y=1283.0)]'
#
# ----------------------------------------

# %% [markdown]
# ### Extract Layout

# %%
for idx, style in enumerate(result.styles):
    print(
        "Document contains {} content".format(
            "handwritten" if style.is_handwritten else "no handwritten"
        )
    )

for page in result.pages:
    print("----Analyzing layout from page #{}----".format(page.page_number))
    print(
        "Page has width: {} and height: {}, measured with unit: {}".format(
            page.width, page.height, page.unit
        )
    )

    for line_idx, line in enumerate(page.lines):
        words = line.get_words()
        print(
            "...Line # {} has word count {} and text '{}' within bounding polygon '{}'".format(
                line_idx,
                len(words),
                line.content,
                line.polygon,
            )
        )

        for word in words:
            print(
                "......Word '{}' has a confidence of {}".format(
                    word.content, word.confidence
                )
            )

    for selection_mark in page.selection_marks:
        print(
            "...Selection mark is '{}' within bounding polygon '{}' and has a confidence of {}".format(
                selection_mark.state,
                selection_mark.polygon,
                selection_mark.confidence,
            )
        )

for table_idx, table in enumerate(result.tables):
    print(
        "Table # {} has {} rows and {} columns".format(
            table_idx, table.row_count, table.column_count
        )
    )
    for region in table.bounding_regions:
        print(
            "Table # {} location on page: {} is {}".format(
                table_idx,
                region.page_number,
                region.polygon,
            )
        )
    for cell in table.cells:
        print(
            "...Cell[{}][{}] has content '{}'".format(
                cell.row_index,
                cell.column_index,
                cell.content,
            )
        )
        for region in cell.bounding_regions:
            print(
                "...content on page {} is within bounding polygon '{}'".format(
                    region.page_number,
                    region.polygon,
                )
            )

print("----------------------------------------")
# Out:
# ----Analyzing layout from page #1----
# Page has width: 1275.0 and height: 1650.0, measured with unit: pixel
# ...Line # 0 has word count 1 and text 'xin' within bounding polygon '[Point(x=78.0, y=90.0), Point(x=175.0, y=83.0), Point(x=177.0, y=139.0), Point(x=78.0, y=142.0)]'
# ......Word 'xin' has a confidence of 0.992
# ...Line # 1 has word count 1 and text 'Cube' within bounding polygon '[Point(x=188.0, y=86.0), Point(x=300.0, y=87.0), Point(x=300.0, y=137.0), Point(x=189.0, y=138.0)]'
# ......Word 'Cube' has a confidence of 0.97
# ...Line # 2 has word count 1 and text 'Invoice' within bounding polygon '[Point(x=798.0, y=55.0), Point(x=904.0, y=55.0), Point(x=904.0, y=83.0), Point(x=798.0, y=83.0)]'
# ......Word 'Invoice' has a confidence of 0.961
# ...Line # 3 has word count 2 and text 'Invoice No.' within bounding polygon '[Point(x=796.0, y=102.0), Point(x=899.0, y=102.0), Point(x=899.0, y=122.0), Point(x=796.0, y=122.0)]'
# ......Word 'Invoice' has a confidence of 0.973
# ......Word 'No.' has a confidence of 0.995
# ...Line # 4 has word count 1 and text 'INV09080012' within bounding polygon '[Point(x=928.0, y=100.0), Point(x=1047.0, y=99.0), Point(x=1047.0, y=123.0), Point(x=928.0, y=124.0)]'
# ......Word 'INV09080012' has a confidence of 0.98
# ...Line # 5 has word count 1 and text 'Date' within bounding polygon '[Point(x=796.0, y=136.0), Point(x=840.0, y=136.0), Point(x=841.0, y=154.0), Point(x=797.0, y=153.0)]'
# ......Word 'Date' has a confidence of 0.993
# ...Line # 6 has word count 1 and text '14-Aug-2009' within bounding polygon '[Point(x=931.0, y=135.0), Point(x=1040.0, y=135.0), Point(x=1040.0, y=156.0), Point(x=931.0, y=156.0)]'
# ......Word '14-Aug-2009' has a confidence of 0.993
# ...Line # 7 has word count 2 and text 'XinCube Inc' within bounding polygon '[Point(x=43.0, y=200.0), Point(x=169.0, y=200.0), Point(x=169.0, y=224.0), Point(x=43.0, y=224.0)]'
# ......Word 'XinCube' has a confidence of 0.994
# ......Word 'Inc' has a confidence of 0.976
# ...Line # 8 has word count 8 and text '380 Francisco St, 94133 San Francisco, CA, US.' within bounding polygon '[Point(x=43.0, y=233.0), Point(x=451.0, y=233.0), Point(x=451.0, y=257.0), Point(x=43.0, y=257.0)]'
# ......Word '380' has a confidence of 0.995
# ......Word 'Francisco' has a confidence of 0.993
# ......Word 'St,' has a confidence of 0.995
# ......Word '94133' has a confidence of 0.995
# ......Word 'San' has a confidence of 0.996
# ......Word 'Francisco,' has a confidence of 0.992
# ......Word 'CA,' has a confidence of 0.995
# ......Word 'US.' has a confidence of 0.995
# ...Line # 9 has word count 6 and text 'Tel: (415) 989-1188 Fax: (415) 989-2288' within bounding polygon '[Point(x=42.0, y=258.0), Point(x=382.0, y=258.0), Point(x=382.0, y=280.0), Point(x=42.0, y=280.0)]'
# ......Word 'Tel:' has a confidence of 0.99
# ......Word '(415)' has a confidence of 0.993
# ......Word '989-1188' has a confidence of 0.992
# ......Word 'Fax:' has a confidence of 0.992
# ......Word '(415)' has a confidence of 0.993
# ......Word '989-2288' has a confidence of 0.994
# ...Line # 10 has word count 2 and text 'Email: admin@xincube.com' within bounding polygon '[Point(x=42.0, y=283.0), Point(x=278.0, y=283.0), Point(x=278.0, y=304.0), Point(x=42.0, y=304.0)]'
# ......Word 'Email:' has a confidence of 0.993
# ......Word 'admin@xincube.com' has a confidence of 0.949
# ...Line # 11 has word count 2 and text 'Website: www.xincube.com' within bounding polygon '[Point(x=42.0, y=305.0), Point(x=272.0, y=306.0), Point(x=272.0, y=326.0), Point(x=42.0, y=326.0)]'
# ......Word 'Website:' has a confidence of 0.995
# ......Word 'www.xincube.com' has a confidence of 0.988
# ...Line # 12 has word count 2 and text 'Bill To' within bounding polygon '[Point(x=41.0, y=387.0), Point(x=102.0, y=387.0), Point(x=102.0, y=410.0), Point(x=40.0, y=409.0)]'
# ......Word 'Bill' has a confidence of 0.99
# ......Word 'To' has a confidence of 0.995
# ...Line # 13 has word count 1 and text 'John' within bounding polygon '[Point(x=131.0, y=390.0), Point(x=178.0, y=391.0), Point(x=178.0, y=409.0), Point(x=131.0, y=409.0)]'
# ......Word 'John' has a confidence of 0.992
# ...Line # 14 has word count 2 and text 'Synex Inc' within bounding polygon '[Point(x=130.0, y=419.0), Point(x=219.0, y=419.0), Point(x=219.0, y=440.0), Point(x=130.0, y=440.0)]'
# ......Word 'Synex' has a confidence of 0.995
# ......Word 'Inc' has a confidence of 0.98
# ...Line # 15 has word count 8 and text '128 AA Juanita Ave, 91740 Glendora, CA, US' within bounding polygon '[Point(x=133.0, y=450.0), Point(x=514.0, y=450.0), Point(x=514.0, y=474.0), Point(x=133.0, y=473.0)]'
# ......Word '128' has a confidence of 0.994
# ......Word 'AA' has a confidence of 0.995
# ......Word 'Juanita' has a confidence of 0.995
# ......Word 'Ave,' has a confidence of 0.992
# ......Word '91740' has a confidence of 0.995
# ......Word 'Glendora,' has a confidence of 0.984
# ......Word 'CA,' has a confidence of 0.995
# ......Word 'US' has a confidence of 0.996
# ...Line # 16 has word count 2 and text 'Ship To' within bounding polygon '[Point(x=611.0, y=389.0), Point(x=682.0, y=389.0), Point(x=682.0, y=411.0), Point(x=611.0, y=410.0)]'
# ......Word 'Ship' has a confidence of 0.993
# ......Word 'To' has a confidence of 0.996
# ...Line # 17 has word count 1 and text 'John' within bounding polygon '[Point(x=710.0, y=390.0), Point(x=757.0, y=390.0), Point(x=757.0, y=409.0), Point(x=711.0, y=408.0)]'
# ......Word 'John' has a confidence of 0.993
# ...Line # 18 has word count 2 and text 'Synex Inc' within bounding polygon '[Point(x=711.0, y=417.0), Point(x=798.0, y=417.0), Point(x=798.0, y=438.0), Point(x=711.0, y=438.0)]'
# ......Word 'Synex' has a confidence of 0.995
# ......Word 'Inc' has a confidence of 0.98
# ...Line # 19 has word count 8 and text '128 AA Juanita Ave, 91740 Glendora, CA, US' within bounding polygon '[Point(x=712.0, y=449.0), Point(x=1095.0, y=449.0), Point(x=1095.0, y=473.0), Point(x=712.0, y=473.0)]'
# ......Word '128' has a confidence of 0.996
# ......Word 'AA' has a confidence of 0.995
# ......Word 'Juanita' has a confidence of 0.992
# ......Word 'Ave,' has a confidence of 0.993
# ......Word '91740' has a confidence of 0.995
# ......Word 'Glendora,' has a confidence of 0.983
# ......Word 'CA,' has a confidence of 0.995
# ......Word 'US' has a confidence of 0.988
# ...Line # 20 has word count 2 and text 'Sales Person' within bounding polygon '[Point(x=53.0, y=570.0), Point(x=170.0, y=570.0), Point(x=170.0, y=590.0), Point(x=53.0, y=589.0)]'
# ......Word 'Sales' has a confidence of 0.993
# ......Word 'Person' has a confidence of 0.994
# ...Line # 21 has word count 2 and text 'Order No' within bounding polygon '[Point(x=273.0, y=571.0), Point(x=355.0, y=571.0), Point(x=355.0, y=589.0), Point(x=273.0, y=589.0)]'
# ......Word 'Order' has a confidence of 0.995
# ......Word 'No' has a confidence of 0.996
# ...Line # 22 has word count 2 and text 'Shipping Date' within bounding polygon '[Point(x=496.0, y=570.0), Point(x=620.0, y=570.0), Point(x=620.0, y=591.0), Point(x=496.0, y=591.0)]'
# ......Word 'Shipping' has a confidence of 0.993
# ......Word 'Date' has a confidence of 0.993
# ...Line # 23 has word count 2 and text 'Shipping Terms' within bounding polygon '[Point(x=718.0, y=570.0), Point(x=859.0, y=570.0), Point(x=859.0, y=591.0), Point(x=718.0, y=591.0)]'
# ......Word 'Shipping' has a confidence of 0.995
# ......Word 'Terms' has a confidence of 0.995
# ...Line # 24 has word count 1 and text 'Terms' within bounding polygon '[Point(x=944.0, y=571.0), Point(x=1001.0, y=572.0), Point(x=1001.0, y=589.0), Point(x=944.0, y=588.0)]'
# ......Word 'Terms' has a confidence of 0.994
# ...Line # 25 has word count 1 and text '13-Aug-2009' within bounding polygon '[Point(x=497.0, y=606.0), Point(x=606.0, y=606.0), Point(x=606.0, y=627.0), Point(x=497.0, y=627.0)]'
# ......Word '13-Aug-2009' has a confidence of 0.994
# ...Line # 26 has word count 1 and text 'COD' within bounding polygon '[Point(x=944.0, y=604.0), Point(x=988.0, y=604.0), Point(x=988.0, y=622.0), Point(x=944.0, y=622.0)]'
# ......Word 'COD' has a confidence of 0.987
# ...Line # 27 has word count 1 and text 'Qty' within bounding polygon '[Point(x=161.0, y=653.0), Point(x=195.0, y=654.0), Point(x=194.0, y=674.0), Point(x=161.0, y=672.0)]'
# ......Word 'Qty' has a confidence of 0.995
# ...Line # 28 has word count 3 and text 'SKU / Description' within bounding polygon '[Point(x=315.0, y=651.0), Point(x=472.0, y=652.0), Point(x=471.0, y=673.0), Point(x=315.0, y=672.0)]'
# ......Word 'SKU' has a confidence of 0.996
# ......Word '/' has a confidence of 0.953
# ......Word 'Description' has a confidence of 0.992
# ...Line # 29 has word count 3 and text 'Unit Price (USD)' within bounding polygon '[Point(x=859.0, y=651.0), Point(x=1002.0, y=651.0), Point(x=1002.0, y=673.0), Point(x=859.0, y=672.0)]'
# ......Word 'Unit' has a confidence of 0.992
# ......Word 'Price' has a confidence of 0.993
# ......Word '(USD)' has a confidence of 0.994
# ...Line # 30 has word count 2 and text 'Amount (USD)' within bounding polygon '[Point(x=1029.0, y=651.0), Point(x=1158.0, y=651.0), Point(x=1157.0, y=672.0), Point(x=1029.0, y=672.0)]'
# ......Word 'Amount' has a confidence of 0.995
# ......Word '(USD)' has a confidence of 0.995
# ...Line # 31 has word count 1 and text '6.00' within bounding polygon '[Point(x=131.0, y=693.0), Point(x=171.0, y=694.0), Point(x=171.0, y=712.0), Point(x=131.0, y=711.0)]'
# ......Word '6.00' has a confidence of 0.993
# ...Line # 32 has word count 3 and text 'AMD Athlon X2DC-7450,' within bounding polygon '[Point(x=320.0, y=692.0), Point(x=528.0, y=692.0), Point(x=528.0, y=713.0), Point(x=320.0, y=713.0)]'
# ......Word 'AMD' has a confidence of 0.997
# ......Word 'Athlon' has a confidence of 0.982
# ......Word 'X2DC-7450,' has a confidence of 0.984
# ...Line # 33 has word count 1 and text '2.4GHz/1GB/160GB/SMP-DVD/VB' within bounding polygon '[Point(x=320.0, y=716.0), Point(x=614.0, y=716.0), Point(x=614.0, y=738.0), Point(x=320.0, y=737.0)]'
# ......Word '2.4GHz/1GB/160GB/SMP-DVD/VB' has a confidence of 0.965
# ...Line # 34 has word count 1 and text '580.00' within bounding polygon '[Point(x=935.0, y=693.0), Point(x=995.0, y=693.0), Point(x=994.0, y=712.0), Point(x=935.0, y=712.0)]'
# ......Word '580.00' has a confidence of 0.995
# ...Line # 35 has word count 1 and text '3,480.00' within bounding polygon '[Point(x=1077.0, y=693.0), Point(x=1153.0, y=693.0), Point(x=1153.0, y=713.0), Point(x=1077.0, y=713.0)]'
# ......Word '3,480.00' has a confidence of 0.994
# ...Line # 36 has word count 1 and text '4.00' within bounding polygon '[Point(x=131.0, y=747.0), Point(x=171.0, y=747.0), Point(x=171.0, y=766.0), Point(x=131.0, y=766.0)]'
# ......Word '4.00' has a confidence of 0.993
# ...Line # 37 has word count 3 and text 'PDC-E5300 - 2.6GHZ/1GB/320GB/SMP-DVD/FDD/VB' within bounding polygon '[Point(x=320.0, y=746.0), Point(x=773.0, y=746.0), Point(x=773.0, y=767.0), Point(x=320.0, y=767.0)]'
# ......Word 'PDC-E5300' has a confidence of 0.995
# ......Word '-' has a confidence of 0.995
# ......Word '2.6GHZ/1GB/320GB/SMP-DVD/FDD/VB' has a confidence of 0.944
# ...Line # 38 has word count 1 and text '645.00' within bounding polygon '[Point(x=934.0, y=747.0), Point(x=995.0, y=747.0), Point(x=995.0, y=766.0), Point(x=934.0, y=766.0)]'
# ......Word '645.00' has a confidence of 0.995
# ...Line # 39 has word count 1 and text '2,580.00' within bounding polygon '[Point(x=1076.0, y=747.0), Point(x=1153.0, y=747.0), Point(x=1153.0, y=767.0), Point(x=1076.0, y=767.0)]'
# ......Word '2,580.00' has a confidence of 0.995
# ...Line # 40 has word count 1 and text '10.00' within bounding polygon '[Point(x=119.0, y=799.0), Point(x=171.0, y=799.0), Point(x=171.0, y=823.0), Point(x=119.0, y=823.0)]'
# ......Word '10.00' has a confidence of 0.995
# ...Line # 41 has word count 3 and text 'LG 18.5" WLCD' within bounding polygon '[Point(x=320.0, y=800.0), Point(x=457.0, y=800.0), Point(x=457.0, y=821.0), Point(x=320.0, y=821.0)]'
# ......Word 'LG' has a confidence of 0.996
# ......Word '18.5"' has a confidence of 0.884
# ......Word 'WLCD' has a confidence of 0.987
# ...Line # 42 has word count 1 and text '230.00' within bounding polygon '[Point(x=934.0, y=802.0), Point(x=995.0, y=802.0), Point(x=995.0, y=820.0), Point(x=934.0, y=820.0)]'
# ......Word '230.00' has a confidence of 0.995
# ...Line # 43 has word count 1 and text '2,300.00' within bounding polygon '[Point(x=1074.0, y=799.0), Point(x=1153.0, y=798.0), Point(x=1153.0, y=823.0), Point(x=1074.0, y=824.0)]'
# ......Word '2,300.00' has a confidence of 0.994
# ...Line # 44 has word count 1 and text '1.00' within bounding polygon '[Point(x=132.0, y=853.0), Point(x=171.0, y=853.0), Point(x=171.0, y=874.0), Point(x=133.0, y=873.0)]'
# ......Word '1.00' has a confidence of 0.992
# ...Line # 45 has word count 3 and text 'HP LaserJet 5200' within bounding polygon '[Point(x=320.0, y=853.0), Point(x=473.0, y=853.0), Point(x=473.0, y=874.0), Point(x=320.0, y=874.0)]'
# ......Word 'HP' has a confidence of 0.995
# ......Word 'LaserJet' has a confidence of 0.98
# ......Word '5200' has a confidence of 0.993
# ...Line # 46 has word count 1 and text '1,103.00' within bounding polygon '[Point(x=922.0, y=854.0), Point(x=995.0, y=853.0), Point(x=995.0, y=874.0), Point(x=922.0, y=875.0)]'
# ......Word '1,103.00' has a confidence of 0.994
# ...Line # 47 has word count 1 and text '1,103.00' within bounding polygon '[Point(x=1079.0, y=853.0), Point(x=1152.0, y=853.0), Point(x=1152.0, y=874.0), Point(x=1079.0, y=875.0)]'
# ......Word '1,103.00' has a confidence of 0.994
# ...Line # 48 has word count 3 and text 'Sub Total (USD)' within bounding polygon '[Point(x=116.0, y=1139.0), Point(x=256.0, y=1139.0), Point(x=256.0, y=1162.0), Point(x=116.0, y=1162.0)]'
# ......Word 'Sub' has a confidence of 0.995
# ......Word 'Total' has a confidence of 0.994
# ......Word '(USD)' has a confidence of 0.994
# ...Line # 49 has word count 2 and text 'Discount (USD)' within bounding polygon '[Point(x=396.0, y=1139.0), Point(x=533.0, y=1139.0), Point(x=533.0, y=1162.0), Point(x=396.0, y=1162.0)]'
# ......Word 'Discount' has a confidence of 0.994
# ......Word '(USD)' has a confidence of 0.993
# ...Line # 50 has word count 2 and text 'Shipping (USD)' within bounding polygon '[Point(x=676.0, y=1140.0), Point(x=813.0, y=1140.0), Point(x=813.0, y=1162.0), Point(x=676.0, y=1162.0)]'
# ......Word 'Shipping' has a confidence of 0.994
# ......Word '(USD)' has a confidence of 0.992
# ...Line # 51 has word count 2 and text 'Total (USD)' within bounding polygon '[Point(x=971.0, y=1140.0), Point(x=1073.0, y=1140.0), Point(x=1073.0, y=1161.0), Point(x=971.0, y=1161.0)]'
# ......Word 'Total' has a confidence of 0.995
# ......Word '(USD)' has a confidence of 0.993
# ...Line # 52 has word count 1 and text '9,463.00' within bounding polygon '[Point(x=154.0, y=1177.0), Point(x=230.0, y=1177.0), Point(x=230.0, y=1197.0), Point(x=154.0, y=1197.0)]'
# ......Word '9,463.00' has a confidence of 0.994
# ...Line # 53 has word count 1 and text '0.00' within bounding polygon '[Point(x=447.0, y=1178.0), Point(x=486.0, y=1178.0), Point(x=486.0, y=1196.0), Point(x=447.0, y=1196.0)]'
# ......Word '0.00' has a confidence of 0.993
# ...Line # 54 has word count 1 and text '0.00' within bounding polygon '[Point(x=726.0, y=1178.0), Point(x=764.0, y=1178.0), Point(x=764.0, y=1196.0), Point(x=726.0, y=1195.0)]'
# ......Word '0.00' has a confidence of 0.993
# ...Line # 55 has word count 1 and text '10,243.70' within bounding polygon '[Point(x=983.0, y=1179.0), Point(x=1065.0, y=1179.0), Point(x=1065.0, y=1199.0), Point(x=983.0, y=1198.0)]'
# ......Word '10,243.70' has a confidence of 0.994
# ...Line # 56 has word count 3 and text 'Sales Tax (USD)' within bounding polygon '[Point(x=114.0, y=1213.0), Point(x=257.0, y=1214.0), Point(x=256.0, y=1236.0), Point(x=114.0, y=1236.0)]'
# ......Word 'Sales' has a confidence of 0.99
# ......Word 'Tax' has a confidence of 0.995
# ......Word '(USD)' has a confidence of 0.993
# ...Line # 57 has word count 2 and text 'Deposit (USD)' within bounding polygon '[Point(x=958.0, y=1214.0), Point(x=1082.0, y=1213.0), Point(x=1082.0, y=1237.0), Point(x=958.0, y=1237.0)]'
# ......Word 'Deposit' has a confidence of 0.994
# ......Word '(USD)' has a confidence of 0.993
# ...Line # 58 has word count 1 and text '780.70' within bounding polygon '[Point(x=162.0, y=1252.0), Point(x=220.0, y=1252.0), Point(x=220.0, y=1276.0), Point(x=162.0, y=1276.0)]'
# ......Word '780.70' has a confidence of 0.993
# ...Line # 59 has word count 1 and text '0.00' within bounding polygon '[Point(x=1007.0, y=1257.0), Point(x=1046.0, y=1258.0), Point(x=1046.0, y=1276.0), Point(x=1007.0, y=1276.0)]'
# ......Word '0.00' has a confidence of 0.993
# ...Line # 60 has word count 3 and text 'Amount Due (USD)' within bounding polygon '[Point(x=936.0, y=1294.0), Point(x=1105.0, y=1294.0), Point(x=1105.0, y=1317.0), Point(x=936.0, y=1317.0)]'
# ......Word 'Amount' has a confidence of 0.994
# ......Word 'Due' has a confidence of 0.995
# ......Word '(USD)' has a confidence of 0.994
# ...Line # 61 has word count 1 and text '10,243.70' within bounding polygon '[Point(x=984.0, y=1331.0), Point(x=1069.0, y=1331.0), Point(x=1069.0, y=1351.0), Point(x=984.0, y=1351.0)]'
# ......Word '10,243.70' has a confidence of 0.987
# ...Line # 62 has word count 20 and text 'All Payments must be made only in the form of a crossed cheque or cash payable to Xin Cube Inc' within bounding polygon '[Point(x=59.0, y=1381.0), Point(x=870.0, y=1381.0), Point(x=870.0, y=1404.0), Point(x=59.0, y=1404.0)]'
# ......Word 'All' has a confidence of 0.988
# ......Word 'Payments' has a confidence of 0.993
# ......Word 'must' has a confidence of 0.992
# ......Word 'be' has a confidence of 0.995
# ......Word 'made' has a confidence of 0.993
# ......Word 'only' has a confidence of 0.992
# ......Word 'in' has a confidence of 0.996
# ......Word 'the' has a confidence of 0.996
# ......Word 'form' has a confidence of 0.992
# ......Word 'of' has a confidence of 0.995
# ......Word 'a' has a confidence of 0.913
# ......Word 'crossed' has a confidence of 0.994
# ......Word 'cheque' has a confidence of 0.994
# ......Word 'or' has a confidence of 0.995
# ......Word 'cash' has a confidence of 0.993
# ......Word 'payable' has a confidence of 0.994
# ......Word 'to' has a confidence of 0.995
# ......Word 'Xin' has a confidence of 0.995
# ......Word 'Cube' has a confidence of 0.992
# ......Word 'Inc' has a confidence of 0.964
# ...Line # 63 has word count 7 and text 'Powered by Xin Invoice (www.xininvoice.com) Free Version' within bounding polygon '[Point(x=56.0, y=1587.0), Point(x=506.0, y=1587.0), Point(x=506.0, y=1609.0), Point(x=56.0, y=1609.0)]'
# ......Word 'Powered' has a confidence of 0.995
# ......Word 'by' has a confidence of 0.995
# ......Word 'Xin' has a confidence of 0.996
# ......Word 'Invoice' has a confidence of 0.973
# ......Word '(www.xininvoice.com)' has a confidence of 0.979
# ......Word 'Free' has a confidence of 0.993
# ......Word 'Version' has a confidence of 0.995
# ...Line # 64 has word count 4 and text 'Page 1 of 1' within bounding polygon '[Point(x=1068.0, y=1588.0), Point(x=1156.0, y=1588.0), Point(x=1156.0, y=1608.0), Point(x=1068.0, y=1608.0)]'
# ......Word 'Page' has a confidence of 0.993
# ......Word '1' has a confidence of 0.995
# ......Word 'of' has a confidence of 0.995
# ......Word '1' has a confidence of 0.995
# Table # 0 has 2 rows and 5 columns
# Table # 0 location on page: 1 is [Point(x=49.0, y=558.0), Point(x=1161.0, y=558.0), Point(x=1161.0, y=635.0), Point(x=49.0, y=635.0)]
# ...Cell[0][0] has content 'Sales Person'
# ...content on page 1 is within bounding polygon '[Point(x=53.0, y=558.0), Point(x=222.0, y=558.0), Point(x=222.0, y=596.0), Point(x=52.0, y=596.0)]'
# ...Cell[0][1] has content 'Order No'
# ...content on page 1 is within bounding polygon '[Point(x=222.0, y=558.0), Point(x=424.0, y=558.0), Point(x=424.0, y=596.0), Point(x=222.0, y=596.0)]'
# ...Cell[0][2] has content 'Shipping Date'
# ...content on page 1 is within bounding polygon '[Point(x=424.0, y=558.0), Point(x=669.0, y=558.0), Point(x=669.0, y=596.0), Point(x=424.0, y=596.0)]'
# ...Cell[0][3] has content 'Shipping Terms'
# ...content on page 1 is within bounding polygon '[Point(x=669.0, y=558.0), Point(x=900.0, y=558.0), Point(x=900.0, y=596.0), Point(x=669.0, y=596.0)]'
# ...Cell[0][4] has content 'Terms'
# ...content on page 1 is within bounding polygon '[Point(x=900.0, y=558.0), Point(x=1089.0, y=558.0), Point(x=1089.0, y=596.0), Point(x=900.0, y=596.0)]'
# ...Cell[1][0] has content ''
# ...content on page 1 is within bounding polygon '[Point(x=52.0, y=596.0), Point(x=222.0, y=596.0), Point(x=222.0, y=633.0), Point(x=52.0, y=633.0)]'
# ...Cell[1][1] has content ''
# ...content on page 1 is within bounding polygon '[Point(x=222.0, y=596.0), Point(x=424.0, y=596.0), Point(x=424.0, y=633.0), Point(x=222.0, y=633.0)]'
# ...Cell[1][2] has content '13-Aug-2009'
# ...content on page 1 is within bounding polygon '[Point(x=424.0, y=596.0), Point(x=669.0, y=596.0), Point(x=669.0, y=633.0), Point(x=424.0, y=633.0)]'
# ...Cell[1][3] has content ''
# ...content on page 1 is within bounding polygon '[Point(x=669.0, y=596.0), Point(x=900.0, y=596.0), Point(x=900.0, y=633.0), Point(x=669.0, y=633.0)]'
# ...Cell[1][4] has content 'COD'
# ...content on page 1 is within bounding polygon '[Point(x=900.0, y=596.0), Point(x=1089.0, y=596.0), Point(x=1089.0, y=633.0), Point(x=900.0, y=633.0)]'
# Table # 1 has 5 rows and 4 columns
# Table # 1 location on page: 1 is [Point(x=48.0, y=635.0), Point(x=1165.0, y=635.0), Point(x=1165.0, y=884.0), Point(x=48.0, y=884.0)]
# ...Cell[0][0] has content 'Qty'
# ...content on page 1 is within bounding polygon '[Point(x=52.0, y=636.0), Point(x=305.0, y=636.0), Point(x=305.0, y=684.0), Point(x=52.0, y=684.0)]'
# ...Cell[0][1] has content 'SKU / Description'
# ...content on page 1 is within bounding polygon '[Point(x=305.0, y=636.0), Point(x=832.0, y=636.0), Point(x=832.0, y=684.0), Point(x=305.0, y=684.0)]'
# ...Cell[0][2] has content 'Unit Price (USD)'
# ...content on page 1 is within bounding polygon '[Point(x=832.0, y=636.0), Point(x=1005.0, y=636.0), Point(x=1005.0, y=685.0), Point(x=832.0, y=684.0)]'
# ...Cell[0][3] has content 'Amount (USD)'
# ...content on page 1 is within bounding polygon '[Point(x=1005.0, y=636.0), Point(x=1161.0, y=636.0), Point(x=1161.0, y=685.0), Point(x=1005.0, y=685.0)]'
# ...Cell[1][0] has content '6.00'
# ...content on page 1 is within bounding polygon '[Point(x=52.0, y=684.0), Point(x=305.0, y=684.0), Point(x=305.0, y=742.0), Point(x=51.0, y=743.0)]'
# ...Cell[1][1] has content 'AMD Athlon X2DC-7450, 2.4GHz/1GB/160GB/SMP-DVD/VB'
# ...content on page 1 is within bounding polygon '[Point(x=305.0, y=684.0), Point(x=832.0, y=684.0), Point(x=832.0, y=742.0), Point(x=305.0, y=742.0)]'
# ...Cell[1][2] has content '580.00'
# ...content on page 1 is within bounding polygon '[Point(x=832.0, y=684.0), Point(x=1005.0, y=685.0), Point(x=1005.0, y=742.0), Point(x=832.0, y=742.0)]'
# ...Cell[1][3] has content '3,480.00'
# ...content on page 1 is within bounding polygon '[Point(x=1005.0, y=685.0), Point(x=1161.0, y=685.0), Point(x=1161.0, y=741.0), Point(x=1005.0, y=742.0)]'
# ...Cell[2][0] has content '4.00'
# ...content on page 1 is within bounding polygon '[Point(x=51.0, y=743.0), Point(x=305.0, y=742.0), Point(x=303.0, y=785.0), Point(x=51.0, y=785.0)]'
# ...Cell[2][1] has content 'PDC-E5300 - 2.6GHZ/1GB/320GB/SMP-DVD/FDD/VB'
# ...content on page 1 is within bounding polygon '[Point(x=305.0, y=742.0), Point(x=832.0, y=742.0), Point(x=832.0, y=785.0), Point(x=303.0, y=785.0)]'
# ...Cell[2][2] has content '645.00'
# ...content on page 1 is within bounding polygon '[Point(x=832.0, y=742.0), Point(x=1005.0, y=742.0), Point(x=1005.0, y=785.0), Point(x=832.0, y=785.0)]'
# ...Cell[2][3] has content '2,580.00'
# ...content on page 1 is within bounding polygon '[Point(x=1005.0, y=742.0), Point(x=1161.0, y=741.0), Point(x=1161.0, y=785.0), Point(x=1005.0, y=785.0)]'
# ...Cell[3][0] has content '10.00'
# ...content on page 1 is within bounding polygon '[Point(x=51.0, y=785.0), Point(x=303.0, y=785.0), Point(x=303.0, y=838.0), Point(x=50.0, y=839.0)]'
# ...Cell[3][1] has content 'LG 18.5" WLCD'
# ...content on page 1 is within bounding polygon '[Point(x=303.0, y=785.0), Point(x=832.0, y=785.0), Point(x=832.0, y=838.0), Point(x=303.0, y=838.0)]'
# ...Cell[3][2] has content '230.00'
# ...content on page 1 is within bounding polygon '[Point(x=832.0, y=785.0), Point(x=1005.0, y=785.0), Point(x=1005.0, y=838.0), Point(x=832.0, y=838.0)]'
# ...Cell[3][3] has content '2,300.00'
# ...content on page 1 is within bounding polygon '[Point(x=1005.0, y=785.0), Point(x=1161.0, y=785.0), Point(x=1161.0, y=838.0), Point(x=1005.0, y=838.0)]'
# ...Cell[4][0] has content '1.00'
# ...content on page 1 is within bounding polygon '[Point(x=50.0, y=839.0), Point(x=303.0, y=838.0), Point(x=303.0, y=885.0), Point(x=50.0, y=885.0)]'
# ...Cell[4][1] has content 'HP LaserJet 5200'
# ...content on page 1 is within bounding polygon '[Point(x=303.0, y=838.0), Point(x=832.0, y=838.0), Point(x=832.0, y=885.0), Point(x=303.0, y=885.0)]'
# ...Cell[4][2] has content '1,103.00'
# ...content on page 1 is within bounding polygon '[Point(x=832.0, y=838.0), Point(x=1005.0, y=838.0), Point(x=1005.0, y=885.0), Point(x=832.0, y=885.0)]'
# ...Cell[4][3] has content '1,103.00'
# ...content on page 1 is within bounding polygon '[Point(x=1005.0, y=838.0), Point(x=1161.0, y=838.0), Point(x=1163.0, y=885.0), Point(x=1005.0, y=885.0)]'
# Table # 2 has 4 rows and 4 columns
# Table # 2 location on page: 1 is [Point(x=48.0, y=1129.0), Point(x=1166.0, y=1129.0), Point(x=1165.0, y=1287.0), Point(x=48.0, y=1287.0)]
# ...Cell[0][0] has content 'Sub Total (USD)'
# ...content on page 1 is within bounding polygon '[Point(x=49.0, y=1129.0), Point(x=325.0, y=1129.0), Point(x=325.0, y=1167.0), Point(x=49.0, y=1167.0)]'
# ...Cell[0][1] has content 'Discount (USD)'
# ...content on page 1 is within bounding polygon '[Point(x=325.0, y=1129.0), Point(x=603.0, y=1129.0), Point(x=603.0, y=1167.0), Point(x=325.0, y=1167.0)]'
# ...Cell[0][2] has content 'Shipping (USD)'
# ...content on page 1 is within bounding polygon '[Point(x=603.0, y=1129.0), Point(x=881.0, y=1129.0), Point(x=881.0, y=1167.0), Point(x=603.0, y=1167.0)]'
# ...Cell[0][3] has content 'Total (USD)'
# ...content on page 1 is within bounding polygon '[Point(x=881.0, y=1129.0), Point(x=1161.0, y=1129.0), Point(x=1161.0, y=1167.0), Point(x=881.0, y=1167.0)]'
# ...Cell[1][0] has content '9,463.00'
# ...content on page 1 is within bounding polygon '[Point(x=49.0, y=1167.0), Point(x=325.0, y=1167.0), Point(x=325.0, y=1203.0), Point(x=49.0, y=1203.0)]'
# ...Cell[1][1] has content '0.00'
# ...content on page 1 is within bounding polygon '[Point(x=325.0, y=1167.0), Point(x=603.0, y=1167.0), Point(x=603.0, y=1203.0), Point(x=325.0, y=1203.0)]'
# ...Cell[1][2] has content '0.00'
# ...content on page 1 is within bounding polygon '[Point(x=603.0, y=1167.0), Point(x=881.0, y=1167.0), Point(x=881.0, y=1204.0), Point(x=603.0, y=1203.0)]'
# ...Cell[1][3] has content '10,243.70'
# ...content on page 1 is within bounding polygon '[Point(x=881.0, y=1167.0), Point(x=1161.0, y=1167.0), Point(x=1161.0, y=1204.0), Point(x=881.0, y=1204.0)]'
# ...Cell[2][0] has content 'Sales Tax (USD)'
# ...content on page 1 is within bounding polygon '[Point(x=49.0, y=1203.0), Point(x=325.0, y=1203.0), Point(x=325.0, y=1242.0), Point(x=49.0, y=1242.0)]'
# ...Cell[2][1] has content ''
# ...content on page 1 is within bounding polygon '[Point(x=325.0, y=1203.0), Point(x=603.0, y=1203.0), Point(x=603.0, y=1242.0), Point(x=325.0, y=1242.0)]'
# ...Cell[2][2] has content ''
# ...content on page 1 is within bounding polygon '[Point(x=603.0, y=1203.0), Point(x=881.0, y=1204.0), Point(x=881.0, y=1242.0), Point(x=603.0, y=1242.0)]'
# ...Cell[2][3] has content 'Deposit (USD)'
# ...content on page 1 is within bounding polygon '[Point(x=881.0, y=1204.0), Point(x=1161.0, y=1204.0), Point(x=1163.0, y=1242.0), Point(x=881.0, y=1242.0)]'
# ...Cell[3][0] has content '780.70'
# ...content on page 1 is within bounding polygon '[Point(x=49.0, y=1242.0), Point(x=325.0, y=1242.0), Point(x=323.0, y=1283.0), Point(x=49.0, y=1283.0)]'
# ...Cell[3][1] has content ''
# ...content on page 1 is within bounding polygon '[Point(x=325.0, y=1242.0), Point(x=603.0, y=1242.0), Point(x=603.0, y=1283.0), Point(x=323.0, y=1283.0)]'
# ...Cell[3][2] has content ''
# ...content on page 1 is within bounding polygon '[Point(x=603.0, y=1242.0), Point(x=881.0, y=1242.0), Point(x=881.0, y=1283.0), Point(x=603.0, y=1283.0)]'
# ...Cell[3][3] has content '0.00'
# ...content on page 1 is within bounding polygon '[Point(x=881.0, y=1242.0), Point(x=1163.0, y=1242.0), Point(x=1163.0, y=1283.0), Point(x=881.0, y=1283.0)]'
# ----------------------------------------
